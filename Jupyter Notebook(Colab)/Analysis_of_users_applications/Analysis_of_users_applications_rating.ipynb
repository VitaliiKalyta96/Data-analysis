# %% [markdown]
# **Analysis of users applications rating**

# %%
import numpy as np
import pandas as pd


applications_path = pd.read_csv("applications(2.0).csv")
industries_path = pd.read_csv("industries(2.0).csv")

industries_data = pd.DataFrame(industries_path)
applications_data = pd.DataFrame(applications_path)

applications_data.head(10)
# Out:
#             Applied at   Amount  Age   Gender                      Industry  \
# 0  11.30.2022 10:26:37  12000.0   29  Чоловік                    Blockchain
# 1  11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 2  11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 3  11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 4  11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
# 5  11.30.2022 10:27:38  16500.0   31  Чоловік                    E-commerce
# 6  11.30.2022 10:27:42   4200.0   30  Чоловік                         Media
# 7  11.30.2022 10:27:44   3600.0   24  Чоловік                    E-commerce
# 8  11.30.2022 10:28:00   1950.0   27  Чоловік                    Automotive
# 9  11.30.2022 10:28:00      NaN   17  Чоловік                          Інша
#
#   Marital status  External Rating                       Education level  \
# 0          Other              8.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 5         Single              8.0  Вища (бакалавр, спеціаліст, магістр)
# 6        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 7        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 8        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 9        Married              2.0                       Ще студент вишу
#
#                       Location                      applicant_id
# 0  Івано-Франківськ чи область  99e7b0dc6cc05dd334d8f38dc26ce9b3
# 1                          NaN  63dfcf8e6904186650d6814279fbe42f
# 2              Київ чи область  10dbafaeb46c09e96b6987c03bbb3498
# 3             Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1
# 4           Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3
# 5              Київ чи область  f720bf9c5c4c3e10a8568c1699847696
# 6              Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271
# 7             Львів чи область  aa54d6e672e4233febadbafdfd048327
# 8             Львів чи область  2eed2883cd1673b21b2ce89d1115c245
# 9                          NaN  9c7a640dccb37d9f2164bac1deb0edfa

# %% [markdown]
# Приберемо дублікати applicant_id.

# %%
# До видалення дублікатів з колонки 'applicant_id'
print("До видалення дублікатів -", applications_data['applicant_id'].shape[0])

# Після видалення дублікатів з колонки 'applicant_id'
applications_data.drop_duplicates(subset="applicant_id", keep="last", inplace=True)
print("Після видалення дублікатів -", applications_data['applicant_id'].shape[0])
# Out:
# До видалення дублікатів - 13315
# Після видалення дублікатів - 13278

# %% [markdown]
# В полі 'External Rating' заповнимо відсутні значення нулями.

# %%
applications_data['External Rating'].fillna(0, inplace=True)
applications_data.head(10)
# Out:
# <ipython-input-3-ec73d13529cd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   applications_data['External Rating'].fillna(0, inplace=True)
#              Applied at   Amount  Age   Gender                      Industry  \
# 1   11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 2   11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 3   11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 4   11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
# 5   11.30.2022 10:27:38  16500.0   31  Чоловік                    E-commerce
# 6   11.30.2022 10:27:42   4200.0   30  Чоловік                         Media
# 7   11.30.2022 10:27:44   3600.0   24  Чоловік                    E-commerce
# 8   11.30.2022 10:28:00   1950.0   27  Чоловік                    Automotive
# 9   11.30.2022 10:28:00      NaN   17  Чоловік                          Інша
# 10  11.30.2022 10:28:03  18000.0   25  Чоловік                        Dating
#
#    Marital status  External Rating                       Education level  \
# 1          Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 2          Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3          Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 4          Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 5          Single              8.0  Вища (бакалавр, спеціаліст, магістр)
# 6         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 7         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 8         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 9         Married              2.0                       Ще студент вишу
# 10         Single              5.0  Вища (бакалавр, спеціаліст, магістр)
#
#               Location                      applicant_id
# 1                  NaN  63dfcf8e6904186650d6814279fbe42f
# 2      Київ чи область  10dbafaeb46c09e96b6987c03bbb3498
# 3     Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1
# 4   Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3
# 5      Київ чи область  f720bf9c5c4c3e10a8568c1699847696
# 6      Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271
# 7     Львів чи область  aa54d6e672e4233febadbafdfd048327
# 8     Львів чи область  2eed2883cd1673b21b2ce89d1115c245
# 9                  NaN  9c7a640dccb37d9f2164bac1deb0edfa
# 10   Дніпро чи область  f8138219d5a95649cc85bdabeb3732ca

# %% [markdown]
# В полі 'Education level' заповнимо відсутні значення текстом “Середня”.

# %%
# Для початку перевіримо, які відповіді записані у дану таблицю.
unique_responses = applications_data['Education level'].unique()
print("Унікальні відповіді у стовпці Education level:", unique_responses, )

# Далі порахуємо кількість там пустих значень до
education_na = applications_data['Education level'].isna()
count_na = education_na.sum()
print("Кількість пустих значень у стовпці Education level до:",count_na)

applications_data['Education level'].fillna('Середня', inplace=True)

# Далі порахуємо кількість там пустих значень після
education_na = applications_data['Education level'].isna()
count_na = education_na.sum()
print("Кількість пустих значень у стовпці Education level після:",count_na)

applications_data.head(10)
# Out:
# Унікальні відповіді у стовпці Education level: ['Вища (бакалавр, спеціаліст, магістр)' 'Ще студент вишу'
#  'Середня спеціальна' 'Середня' 'Дві вищі' nan]
# Кількість пустих значень у стовпці Education level до: 33
# Кількість пустих значень у стовпці Education level після: 0
# <ipython-input-4-fa84b25a5d2f>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   applications_data['Education level'].fillna('Середня', inplace=True)
#              Applied at   Amount  Age   Gender                      Industry  \
# 1   11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 2   11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 3   11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 4   11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
# 5   11.30.2022 10:27:38  16500.0   31  Чоловік                    E-commerce
# 6   11.30.2022 10:27:42   4200.0   30  Чоловік                         Media
# 7   11.30.2022 10:27:44   3600.0   24  Чоловік                    E-commerce
# 8   11.30.2022 10:28:00   1950.0   27  Чоловік                    Automotive
# 9   11.30.2022 10:28:00      NaN   17  Чоловік                          Інша
# 10  11.30.2022 10:28:03  18000.0   25  Чоловік                        Dating
#
#    Marital status  External Rating                       Education level  \
# 1          Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 2          Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3          Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 4          Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 5          Single              8.0  Вища (бакалавр, спеціаліст, магістр)
# 6         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 7         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 8         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 9         Married              2.0                       Ще студент вишу
# 10         Single              5.0  Вища (бакалавр, спеціаліст, магістр)
#
#               Location                      applicant_id
# 1                  NaN  63dfcf8e6904186650d6814279fbe42f
# 2      Київ чи область  10dbafaeb46c09e96b6987c03bbb3498
# 3     Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1
# 4   Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3
# 5      Київ чи область  f720bf9c5c4c3e10a8568c1699847696
# 6      Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271
# 7     Львів чи область  aa54d6e672e4233febadbafdfd048327
# 8     Львів чи область  2eed2883cd1673b21b2ce89d1115c245
# 9                  NaN  9c7a640dccb37d9f2164bac1deb0edfa
# 10   Дніпро чи область  f8138219d5a95649cc85bdabeb3732ca

# %%
# Додамо до цього DataFrame дані з файлу industries.csv, а саме, рейтинги індустрій.
merged_data = pd.merge(applications_data, industries_data)
merged_data.head(5)
# Out:
#             Applied at   Amount  Age   Gender                      Industry  \
# 0  11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 1  11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 2  11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 3  11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
# 4  11.30.2022 10:27:38  16500.0   31  Чоловік                    E-commerce
#
#   Marital status  External Rating                       Education level  \
# 0         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              8.0  Вища (бакалавр, спеціаліст, магістр)
#
#              Location                      applicant_id  Score
# 0                 NaN  63dfcf8e6904186650d6814279fbe42f     20
# 1     Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10
# 2    Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1     15
# 3  Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15
# 4     Київ чи область  f720bf9c5c4c3e10a8568c1699847696     15

# %% [markdown]
# Переводимо стовпець 'Applied at' в формат datetime

# %%
merged_data['Applied at'] = pd.to_datetime(merged_data['Applied at'], format='mixed', dayfirst=True, errors='coerce')
merged_data.head(5)
# Out:
#            Applied at   Amount  Age   Gender                      Industry  \
# 0 2022-11-30 10:26:39      NaN   36  Чоловік  Public services / Government
# 1 2022-11-30 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 2 2022-11-30 10:27:31   1500.0   23    Жінка                       Telecom
# 3 2022-11-30 10:27:34   8400.0   33    Жінка                    Automotive
# 4 2022-11-30 10:27:38  16500.0   31  Чоловік                    E-commerce
#
#   Marital status  External Rating                       Education level  \
# 0         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              8.0  Вища (бакалавр, спеціаліст, магістр)
#
#              Location                      applicant_id  Score
# 0                 NaN  63dfcf8e6904186650d6814279fbe42f     20
# 1     Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10
# 2    Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1     15
# 3  Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15
# 4     Київ чи область  f720bf9c5c4c3e10a8568c1699847696     15

# %% [markdown]
# Розраховано рейтинг заявки за наступними умовами:
#
# - Рейтинг має бути числом від 0 до 100.
#
# - Рейтинг - сума оцінок заявки по 6 критеріям.
#
# - Рейтинг дорівнює нулю, якщо відсутнє значення 'Amount' або якщо 'External Rating' дорівнює нулю.
#
# - Якщо вік заявника між 35 та 55, до рейтингу додається 20 балів.
#
# - Якщо заявка була подана не у вихідні, до рейтингу додається 20 балів.
#
# - Якщо заявника одружений, до рейтингу додається 20 балів.
#
# - Якщо заявника знаходиться в Києві чи області, до рейтингу додається 10 балів
# Значення 'Score' з таблиці industries.csv також додається до заявки (і складає від 0 до 20 балів).
#
# - Якщо 'External Rating' більше чи дорівнює 7, до рейтингу додається 20 балів.
#
# - Якщо 'External Rating' менше чи дорівнює 2, з рейтингу віднімається 20 балів.

# %%
# Функція для розрахунку рейтингу заявки
def calculate_rating(row):

    rating = 0

    # Перевірка на відсутність 'Amount' або 'External Rating'
    if pd.isna(row['Amount']) or row['External Rating'] == 0:
        return 0  # Рейтинг 0, якщо немає 'Amount' або 'External Rating' дорівнює 0

    # Вік заявника (між 35 і 55)
    if 35 <= row['Age'] <= 55:
        rating += 20

    # Час подачі заявки (не у вихідні)
    if pd.to_datetime(row['Applied at']).weekday() < 5:  # weekday() < 5 означає не вихідний
        rating += 20

    # Сімейний стан (якщо одружений)
    if row['Marital status'] == 'Married':
        rating += 20

    # Місцезнаходження (Київ або область)
    if row['Location'] in ['Київ чи область']:  # Перевіряємо, чи знаходиться в Києві чи області
        rating += 10

    # Рейтинг індустрії (значення 'Score' з industries.csv)
    if pd.notna(row['Score']):
        rating += row['Score']

    # Зовнішній рейтинг
    if row['External Rating'] >= 7:
        rating += 20
    elif row['External Rating'] <= 2:
        rating -= 20

    # Обмежуємо рейтинг до діапазону від 0 до 100
    rating = min(max(rating, 0), 100)

    # Повертаємо розрахований рейтинг
    return rating

# Додаємо новий стовпчик 'Rating' з обчисленим рейтингом
merged_data['Rating'] = merged_data.apply(calculate_rating, axis=1)

# Перевіряємо перші кілька рядків об'єднаної таблиці з рейтингами
merged_data.head(10)
# Out:
#            Applied at   Amount  Age   Gender                      Industry  \
# 0 2022-11-30 10:26:39      NaN   36  Чоловік  Public services / Government
# 1 2022-11-30 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 2 2022-11-30 10:27:31   1500.0   23    Жінка                       Telecom
# 3 2022-11-30 10:27:34   8400.0   33    Жінка                    Automotive
# 4 2022-11-30 10:27:38  16500.0   31  Чоловік                    E-commerce
# 5 2022-11-30 10:27:42   4200.0   30  Чоловік                         Media
# 6 2022-11-30 10:27:44   3600.0   24  Чоловік                    E-commerce
# 7 2022-11-30 10:28:00   1950.0   27  Чоловік                    Automotive
# 8 2022-11-30 10:28:00      NaN   17  Чоловік                          Інша
# 9 2022-11-30 10:28:03  18000.0   25  Чоловік                        Dating
#
#   Marital status  External Rating                       Education level  \
# 0         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              8.0  Вища (бакалавр, спеціаліст, магістр)
# 5        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 6        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 7        Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 8        Married              2.0                       Ще студент вишу
# 9         Single              5.0  Вища (бакалавр, спеціаліст, магістр)
#
#              Location                      applicant_id  Score  Rating
# 0                 NaN  63dfcf8e6904186650d6814279fbe42f     20       0
# 1     Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10      40
# 2    Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1     15       0
# 3  Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15      35
# 4     Київ чи область  f720bf9c5c4c3e10a8568c1699847696     15      65
# 5     Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271      5      35
# 6    Львів чи область  aa54d6e672e4233febadbafdfd048327     15      35
# 7    Львів чи область  2eed2883cd1673b21b2ce89d1115c245     15      35
# 8                 NaN  9c7a640dccb37d9f2164bac1deb0edfa     10       0
# 9   Дніпро чи область  f8138219d5a95649cc85bdabeb3732ca      5      25

# %% [markdown]
# В результуючій таблиці залишемо лише заявки з рейтингом більше нуля, ці заявки вважатимуться прийнятими.

# %%
updated_data = merged_data[merged_data['Rating'] > 0]
updated_data.head(10)
# Out:
#             Applied at   Amount  Age   Gender              Industry  \
# 1  2022-11-30 10:26:58   7500.0   34  Чоловік  Adtech / Advertising
# 3  2022-11-30 10:27:34   8400.0   33    Жінка            Automotive
# 4  2022-11-30 10:27:38  16500.0   31  Чоловік            E-commerce
# 5  2022-11-30 10:27:42   4200.0   30  Чоловік                 Media
# 6  2022-11-30 10:27:44   3600.0   24  Чоловік            E-commerce
# 7  2022-11-30 10:28:00   1950.0   27  Чоловік            Automotive
# 9  2022-11-30 10:28:03  18000.0   25  Чоловік                Dating
# 11 2022-11-30 10:28:27   2550.0   20  Чоловік                 Legal
# 12 2022-11-30 10:28:28  18000.0   33  Чоловік              Big Data
# 13 2022-11-30 10:28:39   3000.0   27  Чоловік             Logistics
#
#    Marital status  External Rating                       Education level  \
# 1          Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3          Single              6.0  Вища (бакалавр, спеціаліст, магістр)
# 4          Single              8.0  Вища (бакалавр, спеціаліст, магістр)
# 5         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 6         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 7         Married              1.0  Вища (бакалавр, спеціаліст, магістр)
# 9          Single              5.0  Вища (бакалавр, спеціаліст, магістр)
# 11        Married              1.0                       Ще студент вишу
# 12         Single             10.0  Вища (бакалавр, спеціаліст, магістр)
# 13        Married              3.0  Вища (бакалавр, спеціаліст, магістр)
#
#                        Location                      applicant_id  Score  \
# 1               Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10
# 3            Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15
# 4               Київ чи область  f720bf9c5c4c3e10a8568c1699847696     15
# 5               Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271      5
# 6              Львів чи область  aa54d6e672e4233febadbafdfd048327     15
# 7              Львів чи область  2eed2883cd1673b21b2ce89d1115c245     15
# 9             Дніпро чи область  f8138219d5a95649cc85bdabeb3732ca      5
# 11  Івано-Франківськ чи область  0c792f52f2bf30cdfee53b24b912678a     20
# 12              Київ чи область  28165b1a85ee2e48782cada5f2a660b4     20
# 13         Тернопіль чи область  08323c66f5d8d1e8633aef4f9c9a7cdd     20
#
#     Rating
# 1       40
# 3       35
# 4       65
# 5       35
# 6       35
# 7       35
# 9       25
# 11      40
# 12      70
# 13      60

# %% [markdown]
# Дані з результуючої таблиці згрупуємо за тижнем подачі заявки та виведемо середній рейтинг прийнятих заявок у кожен тиждень.

# %%
# 1. Перетворюємо 'Applied at' у datetime
updated_data['Applied at'] = pd.to_datetime(updated_data['Applied at'], errors='coerce')

# 2. Встановлюємо 'Applied at' як індекс
updated_data = updated_data.set_index('Applied at')

# 3. Групуємо за тижнями і рахуємо середнє
weekly_avg_rating = updated_data['Rating'].resample('W').mean().round(1).dropna().reset_index()

# 4. Перейменовуємо стовпці
weekly_avg_rating.rename(columns={'Applied at': 'Week Start', 'Rating': 'Average Rating'}, inplace=True)
weekly_avg_rating
# Out:
#    Week Start  Average Rating
# 0  2022-01-16            56.9
# 1  2022-02-13            37.0
# 2  2022-03-13            35.3
# 3  2022-04-17            53.0
# 4  2022-05-15            50.2
# 5  2022-06-12            35.0
# 6  2022-07-17            51.1
# 7  2022-08-14            49.5
# 8  2022-09-18            47.9
# 9  2022-10-16            52.1
# 10 2022-11-13            37.6
# 11 2022-12-04            53.5
# 12 2022-12-18            49.8
# 13 2022-12-25            47.0
# 14 2023-01-01            50.9
# 15 2023-02-05            53.5
# 16 2023-03-05            55.1
# 17 2023-04-02            33.4
# 18 2023-05-07            55.0
# 19 2023-06-04            53.0
# 20 2023-07-02            28.8
# 21 2023-08-06            50.2
# 22 2023-09-03            51.9
